# %% [markdown]
# # Installing litert-lm CLI

# %% [markdown]
# LiteRT-LM ist eine leichtgewichtige Orchestrierungsschicht, die speziell dafür entwickelt wurde, große Sprachmodelle effizient auf verschiedenen Endgeräten auszuführen. Sie ermöglicht plattformübergreifendes Arbeiten, nutzt Hardwarebeschleunigung wie GPU und NPU für maximale Performance und unterstützt moderne Funktionen wie Multimodalität und Funktionsaufrufe.

# %% [markdown]
# ## Installation

# %%
# Install to a Python (virtual) environment.
# Ensure using Python 3.10 or above.
# !pip install --upgrade litert-lm
# Out:
# ...
#   Using cached click-8.5.0-py3-none-any.whl.metadata (2.6 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.2/47.2 MB 13.9 MB/s  0:00:03m0:00:0100:01
# ...
# Using cached click-8.5.0-py3-none-any.whl (125 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9/9 [litert-lm]/9 [litert-lm-builder]
# ...

# %% [markdown]
# ## Upgrading

# %%
pip install --upgrade litert-lm

# %% [markdown]
# ## Uninstalling

# %%
pip uninstall litert-lm

# %% [markdown]
# ## Deleting Models and Caches

# %%
rm -r ~/.litert-lm
