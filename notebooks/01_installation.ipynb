# %% [markdown]
# # 🌿 PHASE 1: System-Installation & Umgebungsvorbereitung
# **Projekt: Mai_AI (MaiOmni) — Das private, datenschutzkonforme Multi-User KI-System**
#
# Diese Notebook-Reihe dient als **ausführbare Knotenstelle** für das Deployment des gesamten Stacks. Inspiriert von **Spec-Driven Development (GitHub Spec Kit)** und dem lokalen, modularen Integrationsansatz von **OpenHuman (tinyhumansai)**, strukturieren wir das Projekt in Phasen.
#
# ---
# ### 🎯 Ziele dieser Phase:
# 1. Validierung der Python-Laufzeitumgebung (`MaiOmni` Conda-Environment).
# 2. Überprüfung aller Abhängigkeiten (Docker SDK, Streamlit, IPython, etc.).
# 3. Lokale Hardware-Erkennung (NVIDIA-Support).
# 4. Einrichtung und Herunterladen lokaler LLMs über **Ollama**.
#
# ---

# %%
# Führt das plattformunabhängige Installations-Skript aus
# %run ../src/install/install_MaiOmni.py
# Out:
# [Installer] --- Starte macOS Installation ---
#
# ============================================================
# ============================================================
#
# [Installer] Überspringe Erstellung. Bestehende Umgebung 'MaiOmni' bleibt unverändert.
# [Installer] Installiere/Überprüfe Basis-Pakete in 'MaiOmni'...
# Requirement already satisfied: jupyter in /Users/cristallagus/miniconda3/envs/MaiOmni/lib/python3.10/site-packages (1.1.1)
# Requirement already satisfied: ipykernel in /Users/cristallagus/miniconda3/envs/MaiOmni/lib/python3.10/site-packages (7.2.0)
# Requirement already satisfied: notebook in /Users/cristallagus/miniconda3/envs/MaiOmni/lib/python3.10/site-packages (from jupyter) (7.5.6)
# Requirement already satisfied: jupyter-console in /Users/cristallagus/miniconda3/envs/MaiOmni/lib/python3.10/site-packages (from jupyter) (6.6.3)
# Requirement already satisfied: nbconvert in /Users/cristallagus/miniconda3/envs/MaiOmni/lib/python3.10/site-packages (from jupyter) (7.17.1)
# Requirement already satisfied: ipywidgets in /Users/cristallagus/miniconda3/envs/MaiOmni/lib/python3.10/site-packages (from jupyter) (8.1.8)
# Requirement already satisfied: jupyterlab in /Users/cristallagus/miniconda3/envs/MaiOmni/lib/python3.10/site-packages (from jupyter) (4.5.8)
# Requirement already satisfied: appnope>=0.1.2 in /Users/cristallagus/miniconda3/envs/MaiOmni/lib/python3.10/site-packages (from ipykernel) (0.1.4)
# Requirement already satisfied: comm>=0.1.1 in /Users/cristallagus/miniconda3/envs/MaiOmni/lib/python3.10/site-packages (from ipykernel) (0.2.3)
# Requirement already satisfied: debugpy>=1.6.5 in /Users/cristallagus/miniconda3/envs/MaiOmni/lib/python3.10/site-packages (from ipykernel) (1.8.21)
# Requirement already satisfied: ipython>=7.23.1 in /Users/cristallagus/miniconda3/envs/MaiOmni/lib/python3.10/site-packages (from ipykernel) (8.39.0)
# Requirement already satisfied: jupyter-client>=8.8.0 in /Users/cristallagus/miniconda3/envs/MaiOmni/lib/python3.10/site-packages (from ipykernel) (8.8.0)
# Requirement already satisfied: jupyter-core!=6.0.*,>=5.1 in /Users/cristallagus/miniconda3/envs/MaiOmni/lib/python3.10/site-packages (from ipykernel) (5.9.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in /Users/cristallagus/miniconda3/envs/MaiOmni/lib/python3.10/site-packages (from ipykernel) (0.2.2)
# Requirement already satisfied: nest-asyncio>=1.4 in /Users/cristallagus/miniconda3/envs/MaiOmni/lib/python3.10/site-packages (from ipykernel) (1.6.0)
# Requirement already satisfied: packaging>=22 in /Users/cristallagus/miniconda3/envs/MaiOmni/lib/python3.10/site-packages (from ipykernel) (26.0)
# Requirement already satisfied: psutil>=5.7 in /Users/cristallagus/miniconda3/envs/MaiOmni/lib/python3.10/site-packages (from ipykernel) (7.2.2)
# Requirement already satisfied: pyzmq>=25 in /Users/cristallagus/miniconda3/envs/MaiOmni/lib/python3.10/site-packages (from ipykernel) (27.1.0)
# Requirement already satisfied: tornado>=6.4.1 in /Users/cristallagus/miniconda3/envs/MaiOmni/lib/python3.10/site-packages (from ipykernel) (6.5.6)
# Requirement already satisfied: traitlets>=5.4.0 in /Users/cristallagus/miniconda3/envs/MaiOmni/lib/python3.10/site-packages (from ipykernel) (5.15.1)
# Requirement already satisfied: decorator in /Users/cristallagus/miniconda3/envs/MaiOmni/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel) (5.3.1)
# Requirement already satisfied: exceptiongroup in /Users/cristallagus/miniconda3/envs/MaiOmni/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel) (1.3.1)
# Requirement already satisfied: jedi>=0.16 in /Users/cristallagus/miniconda3/envs/MaiOmni/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel) (0.20.0)
# Requirement already satisfied: pexpect>4.3 in /Users/cristallagus/miniconda3/envs/MaiOmni/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /Users/cristallagus/miniconda3/envs/MaiOmni/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel) (3.0.52)
# Requirement already satisfied: pygments>=2.4.0 in /Users/cristallagus/miniconda3/envs/MaiOmni/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel) (2.20.0)
# Requirement already satisfied: stack_data in /Users/cristallagus/miniconda3/envs/MaiOmni/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel) (0.6.3)
# Requirement already satisfied: typing_extensions>=4.6 in /Users/cristallagus/miniconda3/envs/MaiOmni/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel) (4.15.0)
# Requirement already satisfied: wcwidth in /Users/cristallagus/miniconda3/envs/MaiOmni/lib/python3.10/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel) (0.7.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.6 in /Users/cristallagus/miniconda3/envs/MaiOmni/lib/python3.10/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel) (0.8.7)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/cristallagus/miniconda3/envs/MaiOmni/lib/python3.10/site-packages (from jupyter-client>=8.8.0->ipykernel) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.5 in /Users/cristallagus/miniconda3/envs/MaiOmni/lib/python3.10/site-packages (from jupyter-core!=6.0.*,>=5.1->ipykernel) (4.10.0)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/cristallagus/miniconda3/envs/MaiOmni/lib/python3.10/site-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel) (0.7.0)
# Requirement already satisfied: six>=1.5 in /Users/cristallagus/miniconda3/envs/MaiOmni/lib/python3.10/site-packages (from python-dateutil>=2.8.2->jupyter-client>=8.8.0->ipykernel) (1.17.0)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in /Users/cristallagus/miniconda3/envs/MaiOmni/lib/python3.10/site-packages (from ipywidgets->jupyter) (4.0.15)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in /Users/cristallagus/miniconda3/envs/MaiOmni/lib/python3.10/site-packages (from ipywidgets->jupyter) (3.0.16)
# Requirement already satisfied: async-lru>=1.0.0 in /Users/cristallagus/miniconda3/envs/MaiOmni/lib/python3.10/site-packages (from jupyterlab->jupyter) (2.3.0)
# Requirement already satisfied: httpx<1,>=0.25.0 in /Users/cristallagus/miniconda3/envs/MaiOmni/lib/python3.10/site-packages (from jupyterlab->jupyter) (0.28.1)
# Requirement already satisfied: jinja2>=3.0.3 in /Users/cristallagus/miniconda3/envs/MaiOmni/lib/python3.10/site-packages (from jupyterlab->jupyter) (3.1.6)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in /Users/cristallagus/miniconda3/envs/MaiOmni/lib/python3.10/site-packages (from jupyterlab->jupyter) (2.3.1)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in /Users/cristallagus/miniconda3/envs/MaiOmni/lib/python3.10/site-packages (from jupyterlab->jupyter) (2.19.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.28.0 in /Users/cristallagus/miniconda3/envs/MaiOmni/lib/python3.10/site-packages (from jupyterlab->jupyter) (2.28.0)
# Requirement already satisfied: notebook-shim>=0.2 in /Users/cristallagus/miniconda3/envs/MaiOmni/lib/python3.10/site-packages (from jupyterlab->jupyter) (0.2.4)
# Requirement already satisfied: setuptools>=41.1.0 in /Users/cristallagus/miniconda3/envs/MaiOmni/lib/python3.10/site-packages (from jupyterlab->jupyter) (82.0.1)
# Requirement already satisfied: tomli>=1.2.2 in /Users/cristallagus/miniconda3/envs/MaiOmni/lib/python3.10/site-packages (from jupyterlab->jupyter) (2.4.1)
# Requirement already satisfied: anyio in /Users/cristallagus/miniconda3/envs/MaiOmni/lib/python3.10/site-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter) (4.13.0)
# Requirement already satisfied: certifi in /Users/cristallagus/miniconda3/envs/MaiOmni/lib/python3.10/site-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter) (2026.5.20)
# Requirement already satisfied: httpcore==1.* in /Users/cristallagus/miniconda3/envs/MaiOmni/lib/python3.10/site-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter) (1.0.9)
# Requirement already satisfied: idna in /Users/cristallagus/miniconda3/envs/MaiOmni/lib/python3.10/site-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter) (3.18)
# Requirement already satisfied: h11>=0.16 in /Users/cristallagus/miniconda3/envs/MaiOmni/lib/python3.10/site-packages (from httpcore==1.*->httpx<1,>=0.25.0->jupyterlab->jupyter) (0.16.0)
# Requirement already satisfied: argon2-cffi>=21.1 in /Users/cristallagus/miniconda3/envs/MaiOmni/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (25.1.0)
# Requirement already satisfied: jupyter-events>=0.11.0 in /Users/cristallagus/miniconda3/envs/MaiOmni/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.12.1)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /Users/cristallagus/miniconda3/envs/MaiOmni/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.5.4)
# Requirement already satisfied: nbformat>=5.3.0 in /Users/cristallagus/miniconda3/envs/MaiOmni/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (5.10.4)
# Requirement already satisfied: overrides>=5.0 in /Users/cristallagus/miniconda3/envs/MaiOmni/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (7.7.0)
# Requirement already satisfied: prometheus-client>=0.9 in /Users/cristallagus/miniconda3/envs/MaiOmni/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.25.0)
# Requirement already satisfied: send2trash>=1.8.2 in /Users/cristallagus/miniconda3/envs/MaiOmni/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (2.1.0)
# Requirement already satisfied: terminado>=0.8.3 in /Users/cristallagus/miniconda3/envs/MaiOmni/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in /Users/cristallagus/miniconda3/envs/MaiOmni/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.9.0)
# Requirement already satisfied: babel>=2.10 in /Users/cristallagus/miniconda3/envs/MaiOmni/lib/python3.10/site-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter) (2.18.0)
# Requirement already satisfied: json5>=0.9.0 in /Users/cristallagus/miniconda3/envs/MaiOmni/lib/python3.10/site-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter) (0.14.0)
# Requirement already satisfied: jsonschema>=4.18.0 in /Users/cristallagus/miniconda3/envs/MaiOmni/lib/python3.10/site-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter) (4.26.0)
# Requirement already satisfied: requests>=2.31 in /Users/cristallagus/miniconda3/envs/MaiOmni/lib/python3.10/site-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter) (2.34.2)
# Requirement already satisfied: argon2-cffi-bindings in /Users/cristallagus/miniconda3/envs/MaiOmni/lib/python3.10/site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (25.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/cristallagus/miniconda3/envs/MaiOmni/lib/python3.10/site-packages (from jinja2>=3.0.3->jupyterlab->jupyter) (3.0.3)
# Requirement already satisfied: attrs>=22.2.0 in /Users/cristallagus/miniconda3/envs/MaiOmni/lib/python3.10/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter) (26.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/cristallagus/miniconda3/envs/MaiOmni/lib/python3.10/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/cristallagus/miniconda3/envs/MaiOmni/lib/python3.10/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /Users/cristallagus/miniconda3/envs/MaiOmni/lib/python3.10/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter) (0.30.0)
# Requirement already satisfied: python-json-logger>=2.0.4 in /Users/cristallagus/miniconda3/envs/MaiOmni/lib/python3.10/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (4.1.0)
# Requirement already satisfied: pyyaml>=5.3 in /Users/cristallagus/miniconda3/envs/MaiOmni/lib/python3.10/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (6.0.3)
# Requirement already satisfied: rfc3339-validator in /Users/cristallagus/miniconda3/envs/MaiOmni/lib/python3.10/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /Users/cristallagus/miniconda3/envs/MaiOmni/lib/python3.10/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.1.1)
# Requirement already satisfied: fqdn in /Users/cristallagus/miniconda3/envs/MaiOmni/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.5.1)
# Requirement already satisfied: isoduration in /Users/cristallagus/miniconda3/envs/MaiOmni/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /Users/cristallagus/miniconda3/envs/MaiOmni/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (3.1.1)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in /Users/cristallagus/miniconda3/envs/MaiOmni/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.1.0)
# Requirement already satisfied: uri-template in /Users/cristallagus/miniconda3/envs/MaiOmni/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in /Users/cristallagus/miniconda3/envs/MaiOmni/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (25.10.0)
# Requirement already satisfied: beautifulsoup4 in /Users/cristallagus/miniconda3/envs/MaiOmni/lib/python3.10/site-packages (from nbconvert->jupyter) (4.14.3)
# Requirement already satisfied: bleach!=5.0.0 in /Users/cristallagus/miniconda3/envs/MaiOmni/lib/python3.10/site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter) (6.3.0)
# Requirement already satisfied: defusedxml in /Users/cristallagus/miniconda3/envs/MaiOmni/lib/python3.10/site-packages (from nbconvert->jupyter) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /Users/cristallagus/miniconda3/envs/MaiOmni/lib/python3.10/site-packages (from nbconvert->jupyter) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in /Users/cristallagus/miniconda3/envs/MaiOmni/lib/python3.10/site-packages (from nbconvert->jupyter) (3.2.1)
# Requirement already satisfied: nbclient>=0.5.0 in /Users/cristallagus/miniconda3/envs/MaiOmni/lib/python3.10/site-packages (from nbconvert->jupyter) (0.10.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /Users/cristallagus/miniconda3/envs/MaiOmni/lib/python3.10/site-packages (from nbconvert->jupyter) (1.5.1)
# Requirement already satisfied: webencodings in /Users/cristallagus/miniconda3/envs/MaiOmni/lib/python3.10/site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert->jupyter) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /Users/cristallagus/miniconda3/envs/MaiOmni/lib/python3.10/site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter) (1.4.0)
# Requirement already satisfied: fastjsonschema>=2.15 in /Users/cristallagus/miniconda3/envs/MaiOmni/lib/python3.10/site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (2.21.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/cristallagus/miniconda3/envs/MaiOmni/lib/python3.10/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.26 in /Users/cristallagus/miniconda3/envs/MaiOmni/lib/python3.10/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter) (2.7.0)
# Requirement already satisfied: lark>=1.2.2 in /Users/cristallagus/miniconda3/envs/MaiOmni/lib/python3.10/site-packages (from rfc3987-syntax>=1.1.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.3.1)
# Requirement already satisfied: cffi>=1.0.1 in /Users/cristallagus/miniconda3/envs/MaiOmni/lib/python3.10/site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (2.0.0)
# Requirement already satisfied: pycparser in /Users/cristallagus/miniconda3/envs/MaiOmni/lib/python3.10/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (3.0)
# Requirement already satisfied: soupsieve>=1.6.1 in /Users/cristallagus/miniconda3/envs/MaiOmni/lib/python3.10/site-packages (from beautifulsoup4->nbconvert->jupyter) (2.8.4)
# Requirement already satisfied: arrow>=0.15.0 in /Users/cristallagus/miniconda3/envs/MaiOmni/lib/python3.10/site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.4.0)
# Requirement already satisfied: tzdata in /Users/cristallagus/miniconda3/envs/MaiOmni/lib/python3.10/site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (2026.2)
# Requirement already satisfied: executing>=1.2.0 in /Users/cristallagus/miniconda3/envs/MaiOmni/lib/python3.10/site-packages (from stack_data->ipython>=7.23.1->ipykernel) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/cristallagus/miniconda3/envs/MaiOmni/lib/python3.10/site-packages (from stack_data->ipython>=7.23.1->ipykernel) (3.0.1)
# Requirement already satisfied: pure-eval in /Users/cristallagus/miniconda3/envs/MaiOmni/lib/python3.10/site-packages (from stack_data->ipython>=7.23.1->ipykernel) (0.2.3)
# [Installer] macOS-Setup abgeschlossen!

# %%
# %run ../src/install/install_folder_index.py
# Out:
# 2026-06-15 19:05:23,041 - [INFO] - --- Stochastische Projekt-Initialisierung gestartet ---
# 2026-06-15 19:05:23,041 - [INFO] - Bestätigtes Hauptverzeichnis (Root): /Users/cristallagus/Desktop/GitHub/Offline_AI
# 2026-06-15 19:05:23,042 - [INFO] - [OK - GESCHÜTZT] Begriff 'root' bereits aktiv --> Pfad: /Users/cristallagus/Desktop/GitHub/Offline_AI
# 2026-06-15 19:05:23,042 - [INFO] - [OK - GESCHÜTZT] Begriff 'config' bereits aktiv --> Pfad: /Users/cristallagus/Desktop/GitHub/Offline_AI/config
# 2026-06-15 19:05:23,043 - [INFO] - [OK - GESCHÜTZT] Begriff 'data' bereits aktiv --> Pfad: /Users/cristallagus/Desktop/GitHub/Offline_AI/data
# 2026-06-15 19:05:23,044 - [INFO] - [OK - GESCHÜTZT] Begriff 'knowledge' bereits aktiv --> Pfad: /Users/cristallagus/Desktop/GitHub/Offline_AI/knowledge
# 2026-06-15 19:05:23,044 - [INFO] - [OK - GESCHÜTZT] Begriff 'logs' bereits aktiv --> Pfad: /Users/cristallagus/Desktop/GitHub/Offline_AI/logs
# 2026-06-15 19:05:23,044 - [INFO] - [OK - GESCHÜTZT] Begriff 'notebooks' bereits aktiv --> Pfad: /Users/cristallagus/Desktop/GitHub/Offline_AI/notebooks
# 2026-06-15 19:05:23,045 - [INFO] - [OK - GESCHÜTZT] Begriff 'privacy' bereits aktiv --> Pfad: /Users/cristallagus/Desktop/GitHub/Offline_AI/privacy
# 2026-06-15 19:05:23,045 - [INFO] - [OK - GESCHÜTZT] Begriff 'src' bereits aktiv --> Pfad: /Users/cristallagus/Desktop/GitHub/Offline_AI/src
# 2026-06-15 19:05:23,046 - [INFO] - [OK - GESCHÜTZT] Begriff 'temp' bereits aktiv --> Pfad: /Users/cristallagus/Desktop/GitHub/Offline_AI/temp
# 2026-06-15 19:05:23,046 - [INFO] - [OK - GESCHÜTZT] Begriff 'docker' bereits aktiv --> Pfad: /Users/cristallagus/Desktop/GitHub/Offline_AI/docker
# 2026-06-15 19:05:23,047 - [INFO] - [OK - GESCHÜTZT] Begriff 'Install' bereits aktiv --> Pfad: /Users/cristallagus/Desktop/GitHub/Offline_AI/src/Install
# 2026-06-15 19:05:23,047 - [INFO] - [OK - GESCHÜTZT] Begriff 'Jarvis' bereits aktiv --> Pfad: /Users/cristallagus/Desktop/GitHub/Offline_AI/src/Jarvis
# 2026-06-15 19:05:23,047 - [INFO] - [OK - GESCHÜTZT] Begriff 'docker_py' bereits aktiv --> Pfad: /Users/cristallagus/Desktop/GitHub/Offline_AI/src/docker_py
# 2026-06-15 19:05:23,048 - [INFO] - Globale Pfad-Begriffe erfolgreich gesichert in: /Users/cristallagus/Desktop/GitHub/Offline_AI/config/project_paths.json
# 2026-06-15 19:05:23,050 - [INFO] - --- Projekt-Initialisierung erfolgreich beendet ---

# %%
# %run ../src/install/install_docker.py

import docker
# !docker --version
# Out:
# [✓] Das Python-Modul 'docker' ist bereits in 'MaiOmni' aktiv.
# Alle notwendigen Module wurden erfolgreich geladen.
#
# --- Prüfe System-Umgebung ---
# [!] Docker CLI gefunden, aber der Docker-Daemon schläft.
# -> Bitte starte 'Docker Desktop' manuell über deine Anwendungen.
#
# Docker version 29.5.2, build 79eb04c

# %% [markdown]
# ### 📦 Schritt 1: Conda-Umgebung & Bibliotheken prüfen
# Wir prüfen, ob die notwendigen Core-Bibliotheken im Conda-Environment aktiv sind.

# %%
# Starte den Installer für Umgebungskonfiguration
print("--- Bibliotheken-Check gestartet ---")
# %run ../src/install/python_library_config.py
# Out:
# --- Bibliotheken-Check gestartet ---
# 2026-06-15 19:03:41,040 - LibraryChecker - INFO - Analysiere installierte Python-Bibliotheken...
# 2026-06-15 19:03:41,123 - LibraryChecker - INFO - Erfolgreich! Gespeichert in: /Users/cristallagus/Desktop/GitHub/Offline_AI/config/python_library_config.json

# %% [markdown]
# ### 🖥️ Schritt 2: Hardware-Kapazitäten ermitteln & Ollama-Setup
# Jetzt scannen wir das System auf GPU-Verfügbarkeit (CUDA / Apple Silicon), um die Modellgröße (z. B. Codestral 22B, Llama3 8B, oder Phi3) optimal an deine Hardware anzupassen.

# %%
# %run ../src/install/capacity_hardware_config.py
# 2. Lädt aus JSON, falls vorhanden, sonst Live-Analyse
capacity.load_or_analyze()

print("--- Hardware-Analyse ---")
print(f"Erkannte CPU-Kerne: {capacity.physical_cores}")
print(f"RAM: {capacity.ram_gb:.2f} GB")
print(f"Gerätetyp: {capacity.device_type}")

print("\n--- Starte Ollama-Modellbereitstellung ---")
# %run ../src/install/active_ollama_hardware_downloader.py
# Out:
# [INFO] Konfiguration erfolgreich aus '/Users/cristallagus/Desktop/GitHub/Offline_AI/config/hardware_config.json' geladen (Cache).
# =============================================
#  LOGISTIK-REPORT: SYSTEM CAPACITY
# =============================================
# Gerätetyp:       Notebook / Laptop
# Betriebssystem:  Darwin (Rel: 25.2.0)
# Architektur:     arm64
# Prozessor:       arm
# CPU-Kerne:       8 physisch / 8 logisch
# Arbeitsspeicher: 16.0 GB
# =============================================
# [INFO] Konfiguration erfolgreich aus '/Users/cristallagus/Desktop/GitHub/Offline_AI/config/hardware_config.json' geladen (Cache).
# --- Hardware-Analyse ---
# Erkannte CPU-Kerne: 8
# RAM: 16.00 GB
# Gerätetyp: Notebook / Laptop
#
# --- Starte Ollama-Modellbereitstellung ---
# 2026-06-15 19:13:14,408 - [INFO] - === Start der automatisisierten Ollama-Hardware-Analyse ===
# [INFO] Stelle Verbindung zum zentralen Open-Source-Repository her...
# 2026-06-15 19:13:14,408 - [INFO] - Rufe aktuelle Modell-Bibliothek aus dem Internet ab...
# [INFO] Modell-Metadaten erfolgreich empfangen.
# [INFO] Starte Hardware-Leistungs-Check...
# 2026-06-15 19:13:16,178 - [INFO] - Geräte-Leistungs-Check: 16.0 GB RAM erkannt.
# 2026-06-15 19:13:16,179 - [INFO] - Berechnete maximale Obergrenze für Modellgröße: 11.2 GB.
#
# ================================================================================
#  SYSTEM-ANALYSE REPRODUZIERT:
#  -> VERFÜGGBARER ARBEITSSPEICHER : 16.0 GB RAM
#  -> MAXIMALES SCHUTZ-BUDGET     : 11.2 GB
#  -> GEWÄHLTES KI-OPTIMUM        : Codestral (4.0 GB)
# ================================================================================
#  Einsatzbereich: Readme Codestral Codestral is Mistral AI’s first-ever code model designed for code generation tasks. It is a 22B model. Fluent in 80+ programming languages Codestral is trained on a dataset of over 80 programming languages, including Python, Java, C, C++, JavaScript, Swift, Fortran and Bash. The model can complete coding functions, write tests, and complete any partial code using a fill-in-the-middle mechanism. Benchmarks Reference Mistral AI - Codestral: Hello, World Write Preview # Codestral ![Codestral Hello World](https://ollama.com/assets/mchiang0610/test1/76bfd7f0-fccd-431b-95fe-dddf5a422dcf) Codestral is Mistral AI's first-ever code model designed for code generation tasks. It is a 22B model. ### Fluent in 80+ programming languages Codestral is trained on a dataset of over 80 programming languages, including Python, Java, C, C++, JavaScript, Swift, Fortran and Bash. The model can complete coding functions, write tests, and complete any partial code using a fill-in-the-middle mechanism. ### Benchmarks ![With its larger context window of 32k (compared to 4k, 8k or 16k for competitors), Codestral outperforms all other models in RepoBench, a long-range eval for code generation](https://ollama.com/assets/mchiang0610/test1/f5ea9604-669b-4de0-957d-41245e33636c) ![Benchmarks](https://ollama.com/assets/mchiang0610/test1/e42a01d3-4f36-4d60-a0c8-74ad10159cdd) ![FIM benchmarks](https://ollama.com/assets/mchiang0610/test1/8ca203e2-7bfd-4081-98c8-1ecc3cc46ef8) ### Reference [Mistral AI - Codestral: Hello, World](https://mistral.ai/news/codestral/) Paste, drop or click to upload images (.png, .jpeg, .jpg, .svg, .gif)
# ================================================================================
#
# [AUTOMATION] Starte direkten Download für Core-Modell: 'Codestral'
# 2026-06-15 19:13:16,180 - [INFO] - Starte automatisisierten Download für: 'Codestral'
# Bitte stelle sicher, dass die Ollama-App im Hintergrund läuft.
#
# Status: pulling manifest
# Übertrage Daten-Layer [sha256:22a84]...
# Fortschritt: 100.00% (11986MB / 11986MB) | Status: pulling 22a849aafe3d
# Übertrage Daten-Layer [sha256:51707]...
# Fortschritt: 100.00% (0MB / 0MB) | Status: pulling 51707752a87c
# Übertrage Daten-Layer [sha256:5b686]...
# Fortschritt: 100.00% (0MB / 0MB) | Status: pulling 5b68668f65de
# Übertrage Daten-Layer [sha256:5dea4]...
# Fortschritt: 100.00% (0MB / 0MB) | Status: pulling 5dea4f4d0fff
# Übertrage Daten-Layer [sha256:2be23]...
# Status: success manifest digest) | Status: pulling 2be2362e38c7
#
# 2026-06-15 19:13:16,960 - [INFO] - Erfolgreich! 'Codestral' wurde hardwarekonform installiert.
# 2026-06-15 19:13:16,962 - [INFO] - Aktiver System-Status gesichert in: /Users/cristallagus/Desktop/GitHub/Offline_AI/config/active_model_config.json
# --- Prozess fehlerfrei beendet. Dein Jarvis-Kern steht! ---

# %% [markdown]
# ### 🔄 Was kommt als Nächstes?
# Deine lokale KI-Umgebung und Basis-Bibliotheken sind nun vollständig eingerichtet.
#
# Fahre fort mit dem nächsten Knotenpunkt:
# 👉 **[02_dockereinstellung.ipynb](file:notebooks/02_dockereinstellung.ipynb)** um das Traefik-Netzwerk und den OAuth-Proxy hochzufahren.
